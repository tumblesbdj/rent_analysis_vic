# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import concurrent.futures
import time

# %%
# Max 1000 property links per suburb

def get_property_links(suburb, postcode, max_pages=50):
    # Base URL for the property listings with placeholders for suburb and postcode
    base_url = f'https://www.domain.com.au/rent/{suburb}-vic-{postcode}/?sort=price-desc&page='
    property_links = []

    # Loop through the pages up to the maximum specified
    for page in range(1, max_pages + 1):
        url = base_url + str(page)

        try:
            # Make a GET request to the URL with a specified User-Agent header
            response = requests.get(url, headers={'User-Agent': 'PostmanRuntime/7.6.0'})
        except requests.ConnectionError as e:
            # Handle connection errors and continue to the next page
            print(f"CONNECTION_ERROR: Failed to retrieve page {page}, {suburb}, {postcode}. Error: {e}. Exiting loop.")
            continue

        # Handle rate limiting by checking for a 403 status code
        if response.status_code == 403:
            print(f"RATE_LIMITING: Failed to retrieve page {page}, {suburb}, {postcode}. Status code: {response.status_code}. Exiting loop.")
            break

        # Handle incorrect suburb names by checking for a 404 status code
        if response.status_code == 404:
            print(f"SUBURB_NOT_FOUND: Failed to retrieve page {page}, {suburb}, {postcode} likely due to incorrect suburb name. Status code: {response.status_code}. Exiting loop.")
            break
        
        # Check if the response status code is not 200 and handle it
        elif response.status_code != 200:
            print(f"Failed to retrieve page {page}, {suburb}, {postcode}. Status code: {response.status_code}. Exiting loop.")
            break
        
        # Parse the response content using BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all listings with the class 'address'
        listings = soup.find_all('a', class_='address')

        # If no listings are found, exit the loop
        if not listings:
            print(f"NO LISTINGS: No listings found on page {page}, {suburb}, {postcode}. Exiting loop.")
            break

        # Extract the href attribute from each listing and add it to the property_links list
        for listing in listings:
            link = listing.get('href')
            if link:
                property_links.append(link)

        # Sleep for 1 second to avoid overwhelming the server
        time.sleep(1)
    
    # Return the list of property links
    return property_links

# %%
# Initialize a dictionary to store property data with all fields set to None
empty_data = {
    'title': None,                  # Title of the property listing
    'description': None,            # Description of the property
    'street_address': None,         # Street address of the property
    'suburb': None,                 # Suburb where the property is located
    'postcode': None,               # Postcode of the property's location
    'price': None,                  # Price of the property
    'bedrooms': None,               # Number of bedrooms in the property
    'bathrooms': None,              # Number of bathrooms in the property
    'parking': None,                # Number of parking spaces available
    'primary_property_type': None,  # Primary type of the property (e.g., house, apartment)
    'property_features': None,      # Features of the property (e.g., pool, garden)
    'structured_features': None,    # Structured features of the property (e.g., floor area)
    'video_count': None,            # Number of videos available for the property
    'photo_count': None,            # Number of photos available for the property
    'date_listed': None,            # Date when the property was listed
    'days_listed': None,            # Number of days the property has been listed
    'floor_plans_count': None,      # Number of floor plans available for the property
    'virtual_tour': None,           # Availability of a virtual tour for the property
    'nbn_details': None,            # NBN (National Broadband Network) details for the property
    'nearby_schools': None,         # Information about nearby schools
}

# %%
def extract_property_details(soup):
    # Locate the JSON data embedded in the HTML
    script_data = soup.find('script', id='__NEXT_DATA__').string
    json_data = json.loads(script_data)

    # Use .get() to safely access keys that may or may not be present
    layout_props = json_data.get('props', {}).get('pageProps', {}).get('layoutProps', {})
    property_details = layout_props.get("digitalData", {}).get("page", {}).get("pageInfo", {}).get("property", {})
    component_props = json_data.get('props', {}).get('pageProps', {}).get('componentProps', {})

    # Extract property details into a dictionary
    data = {
        'title': layout_props.get('title', None),
        'description': layout_props.get('description', None),
        'street_address': property_details.get('address', None),
        'suburb': property_details.get('suburb', None),
        'postcode': property_details.get('postcode', None),
        'price': property_details.get('price', None),
        'bedrooms': property_details.get('bedrooms', None),
        'bathrooms': property_details.get('bathrooms', None),
        'parking': property_details.get('parking', None),
        'primary_property_type': property_details.get('primaryPropertyType', None),
        'property_features': property_details.get('propertyFeatures', None),
        'structured_features': property_details.get('structuredFeatures', []),  # Default empty list
        'video_count': property_details.get('videoCount', None),
        'photo_count': property_details.get('photoCount', None),
        'date_listed': property_details.get('dateListed', None),
        'days_listed': property_details.get('daysListed', None),
        'floor_plans_count': property_details.get('floorPlansCount', None),
        'virtual_tour': property_details.get('virtualTour', None),
        'nbn_details': layout_props.get('nbnDetails', None),
        'nearby_schools': component_props.get('schoolCatchment', {}).get('schools', []),  # Default empty list
    }

    return data

# %%
def scrape_property(url):
    # Fetch the page content
    try:
        response = requests.get(url, headers={'User-Agent': 'PostmanRuntime/7.6.0'})
    except requests.ConnectionError as e:
        # Handle connection errors
        print(f"CONNECTION_ERROR: Failed to retrieve page. Error: {e}. Exiting loop.")
        return None
    
    # Handle rate limiting by checking for a 403 status code
    if response.status_code == 403:
        print(f"RATE_LIMITING: Failed to retrieve page {url}. Status code: {response.status_code}. Exiting loop.")
        return None  # Exit the function early if rate-limited

    # Check if the response status code is not 200
    elif response.status_code != 200:
        print(f"Failed to retrieve page {url}. Status code: {response.status_code}. Exiting loop.")
        return None
    
    # Parse the response content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the property details
    property_data = extract_property_details(soup)

    # Sleep for 0.5 seconds to avoid overwhelming the server
    time.sleep(0.5)
    
    return property_data

# %%
# Load the postcode mapping from the JSON file
with open('../../data/landing/postcode_mapping.json', 'r') as json_file:
    postcode_mapping = json.load(json_file)

# %%
def collect_all_property_links_threaded(postcode_mapping, max_workers=5):
    # Initialize an empty list to store all property links
    all_property_links = []
    
    # Create a ThreadPoolExecutor to manage threads
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = []
        
        # Iterate over the postcode mapping dictionary
        for postcode, suburbs in postcode_mapping.items():
            # Iterate over each suburb in the list of suburbs for the current postcode
            for suburb in suburbs:
                # Submit a task to the executor to get property links for the suburb and postcode
                futures.append(executor.submit(get_property_links, suburb, postcode))
                # Sleep for 0.5 seconds to avoid overwhelming the server
                time.sleep(0.5)

        # Process the completed futures as they finish
        for future in concurrent.futures.as_completed(futures):
            # If the future result is not None, extend the all_property_links list with the result
            if future.result() is not None:
                all_property_links.extend(future.result())
            
    # Return the list of all collected property links
    return all_property_links

# %%
def scrape_properties_threaded(property_links, max_workers=5):
    # Initialize an empty list to store all scraped property details
    all_properties = []
    
    # Create a ThreadPoolExecutor to manage threads
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = []
        
        # Iterate over the list of property links
        for i, url in enumerate(property_links):
            # Submit a task to the executor to scrape property details from the URL
            futures.append(executor.submit(scrape_property, url))
            # Sleep for 0.5 seconds to avoid overwhelming the server
            time.sleep(0.5)
        
        # Process the completed futures as they finish
        for future in concurrent.futures.as_completed(futures):
            # If the future result is not None, append the result to the all_properties list
            if future.result() is not None:
                all_properties.append(future.result())

    # Convert the list of all properties to a DataFrame
    df = pd.DataFrame(all_properties)
    # Return the DataFrame
    return df

# %%
# Warning: This will take a long time to run (20-40 mins)
# Status codes 404 are common because of duplicate suburb names, so don't worry about them
# Status codes 403 are rate limiting, so you may need to slow down your requests

# Recommended max_workers = 20. If you get rate limited, reduce the number of workers
property_links = collect_all_property_links_threaded(postcode_mapping, 15)
# Out:
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 3001 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, East Melbourne, 3002 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, West Melbourne, 3003 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, World Trade Centre, 3005 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, University Of Melbourne, 3010 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, West Footscray, 3012 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, South Kingsville, 3015 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Williamstown North, 3016 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 9, Williamstown, 3016. Exiting loop.
# NO LISTINGS: No listings found on page 12, Tottenham, 3012. Exiting loop.
# NO LISTINGS: No listings found on page 12, Newport, 3015. Exiting loop.
# NO LISTINGS: No listings found on page 10, Altona, 3018. Exiting loop.
# NO LISTINGS: No listings found on page 14, Brooklyn, 3012. Exiting loop.
# NO LISTINGS: No listings found on page 3, Seaholme, 3018. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Sunshine North, 3020 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Sunshine West, 3020 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 15, Kingsville, 3012. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Kings Park, 3021 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 15, Seddon, 3011. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, St Albans, 3021 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 16, Spotswood, 3015. Exiting loop.
# NO LISTINGS: No listings found on page 7, Albanvale, 3021. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Caroline Springs, 3023 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Deer Park, 3023 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 20, Maidstone, 3012. Exiting loop.
# NO LISTINGS: No listings found on page 10, Sunshine, 3020. Exiting loop.
# NO LISTINGS: No listings found on page 7, Burnside, 3023. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Mount Cottrell, 3024 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Wyndham Vale, 3024 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Altona North, 3025 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Laverton North, 3026 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Laverton Raaf, 3027 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 11, Braybrook, 3019. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Williams Raaf, 3027 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 10, Albion, 3020. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Altona Meadows, 3028 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Hoppers Crossing, 3029 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 10, Kealba, 3021. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Chartwell, 3030 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 10, Ardeer, 3022. Exiting loop.
# NO LISTINGS: No listings found on page 10, Cairnlea, 3023. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Point Cook, 3030 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 29, Footscray, 3011. Exiting loop.
# NO LISTINGS: No listings found on page 28, Yarraville, 3013. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Werribee South, 3030 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 17, Cocoroc, 3030. Exiting loop.
# NO LISTINGS: No listings found on page 18, Seabrook, 3028. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Ascot Vale, 3032 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Highpoint City, 3032 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 22, Laverton, 3028. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Keilor East, 3033 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 26, Mambourin, 3024. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Avondale Heights, 3034 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Keilor North, 3036 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Calder Park, 3037 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Plumpton, 3037 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Taylors Hill, 3037 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Keilor Downs, 3038 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Keilor Lodge, 3038 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Taylors Lakes, 3038 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Moonee Ponds, 3039 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 4, Sydenham, 3037. Exiting loop.
# NO LISTINGS: No listings found on page 8, Keilor, 3036. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Essendon West, 3040 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Essendon North, 3041 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 9, Delahey, 3037. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Strathmore Heights, 3041 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Airport West, 3042 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Keilor Park, 3042 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 25, Flemington, 3031. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Gladstone Park, 3043 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 12, Aberfeldie, 3040. Exiting loop.
# NO LISTINGS: No listings found on page 18, Travancore, 3032. Exiting loop.
# NO LISTINGS: No listings found on page 23, Kensington, 3031. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Pascoe Vale, 3044 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne Airport, 3045 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Pascoe Vale South, 3044 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 45, Ravenhall, 3023. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Oak Park, 3046 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 37, Quandong, 3030. Exiting loop.
# NO LISTINGS: No listings found on page 10, Niddrie, 3042. Exiting loop.
# NO LISTINGS: No listings found on page 17, Hillside, 3037. Exiting loop.
# NO LISTINGS: No listings found on page 4, Dallas, 3047. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Meadow Heights, 3048 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 7, Tullamarine, 3043. Exiting loop.
# NO LISTINGS: No listings found on page 11, Gowanbrae, 3043. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Royal Melbourne Hospital, 3050 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, North Melbourne, 3051 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 14, Strathmore, 3041. Exiting loop.
# NO LISTINGS: No listings found on page 47, Tarneit, 3029. Exiting loop.
# NO LISTINGS: No listings found on page 17, Essendon, 3040. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Carlton North, 3054 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Princes Hill, 3054 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Brunswick West, 3055 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 3, Attwood, 3049. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Brunswick East, 3057 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Coburg North, 3058 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Moreland, 3058 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 29, Maribyrnong, 3032. Exiting loop.
# NO LISTINGS: No listings found on page 43, Derrimut, 3030. Exiting loop.
# NO LISTINGS: No listings found on page 9, Jacana, 3047. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Oaklands Junction, 3063 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 7, Westmeadows, 3049. Exiting loop.
# NO LISTINGS: No listings found on page 12, Broadmeadows, 3047. Exiting loop.
# NO LISTINGS: No listings found on page 13, Hadfield, 3046. Exiting loop.
# NO LISTINGS: No listings found on page 14, Glenroy, 3046. Exiting loop.
# NO LISTINGS: No listings found on page 47, Werribee, 3030. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Roxburgh Park, 3064 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 16, Coolaroo, 3048. Exiting loop.
# NO LISTINGS: No listings found on page 15, Greenvale, 3059. Exiting loop.
# NO LISTINGS: No listings found on page 14, Yuroke, 3063. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Clifton Hill, 3068 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Fitzroy North, 3068 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 19, Brunswick, 3056. Exiting loop.
# NO LISTINGS: No listings found on page 19, Fawkner, 3060. Exiting loop.
# NO LISTINGS: No listings found on page 15, Mickleham, 3064. Exiting loop.
# NO LISTINGS: No listings found on page 15, Kalkallo, 3064. Exiting loop.
# NO LISTINGS: No listings found on page 17, Somerton, 3062. Exiting loop.
# NO LISTINGS: No listings found on page 18, Donnybrook, 3064. Exiting loop.
# NO LISTINGS: No listings found on page 20, Craigieburn, 3064. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Epping Dc, 3076 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 25, Coburg, 3058. Exiting loop.
# NO LISTINGS: No listings found on page 22, Campbellfield, 3061. Exiting loop.
# NO LISTINGS: No listings found on page 13, Northcote, 3070. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Ivanhoe East, 3079 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 21, Fitzroy, 3065. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Heidelberg Heights, 3081 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Heidelberg Rgh, 3081 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Heidelberg West, 3081 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Mill Park, 3082 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 12, Lalor, 3075. Exiting loop.
# NO LISTINGS: No listings found on page 11, Alphington, 3078. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, La Trobe University, 3083 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 20, Collingwood, 3066. Exiting loop.
# NO LISTINGS: No listings found on page 13, Thomastown, 3074. Exiting loop.
# NO LISTINGS: No listings found on page 20, Preston, 3072. Exiting loop.
# NO LISTINGS: No listings found on page 6, Rosanna, 3084. Exiting loop.
# NO LISTINGS: No listings found on page 6, Eaglemont, 3084. Exiting loop.
# NO LISTINGS: No listings found on page 9, Kingsbury, 3083. Exiting loop.
# NO LISTINGS: No listings found on page 16, Fairfield, 3078. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1
Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Chelsea Heights, 3196 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 16, Ripponlea, 3185. Exiting loop.
# NO LISTINGS: No listings found on page 6, Mordialloc, 3195. Exiting loop.
# NO LISTINGS: No listings found on page 15, Brighton, 3186. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Patterson Lakes, 3197 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 4, Bonbeach, 3196. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Frankston South, 3199 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Frankston North, 3200 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 7, Braeside, 3195. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Carrum Downs, 3201 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 3, Chelsea, 3196. Exiting loop.
# NO LISTINGS: No listings found on page 9, Mentone, 3194. Exiting loop.
# NO LISTINGS: No listings found on page 21, Balaclava, 3183. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, South Melbourne, 3205 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, South Melbourne Dc, 3205 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Albert Park, 3206 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 17, Moorabbin, 3189. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Middle Park, 3206 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Port Melbourne, 3207 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Little River, 3211 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 22, Elsternwick, 3185. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Point Wilson, 3212 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 6, Edithvale, 3196. Exiting loop.
# NO LISTINGS: No listings found on page 6, Carrum, 3197. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, North Shore, 3214 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Bell Park, 3215 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Bell Post Hill, 3215 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 9, Waterways, 3195. Exiting loop.
# NO LISTINGS: No listings found on page 25, Elwood, 3184. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Hamlyn Heights, 3215 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, North Geelong, 3215 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 6, Avalon, 3212. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Freshwater Creek, 3216 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 4, Rippleside, 3215. Exiting loop.
# NO LISTINGS: No listings found on page 7, Corio, 3214. Exiting loop.
# NO LISTINGS: No listings found on page 7, Lara, 3212. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Mount Duneed, 3216 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 10, Frankston, 3199. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Wandana Heights, 3216 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Waurn Ponds, 3216 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Geelong West, 3218 likely due to incorrect suburb name. Status code: 404. Exiting loop.SUBURB_NOT_FOUND: Failed to retrieve page 1, Deakin University, 3217 likely due to incorrect suburb name. Status code: 404. Exiting loop.
#
# NO LISTINGS: No listings found on page 11, Seaford, 3198. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Manifold Heights, 3218 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Herne Hill, 3218 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, East Geelong, 3219 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, St Albans Park, 3219 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 10, Mckinnon, 3204. Exiting loop.
# NO LISTINGS: No listings found on page 8, Norlane, 3214. Exiting loop.
# NO LISTINGS: No listings found on page 12, Heatherton, 3202. Exiting loop.
# NO LISTINGS: No listings found on page 13, Bentleigh, 3204. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, South Geelong, 3220 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 5, Newcomb, 3219. Exiting loop.
# NO LISTINGS: No listings found on page 5, Whittington, 3219. Exiting loop.
# NO LISTINGS: No listings found on page 11, Drumcondra, 3215. Exiting loop.
# NO LISTINGS: No listings found on page 8, Thomson, 3219. Exiting loop.
# NO LISTINGS: No listings found on page 17, Ormond, 3204. Exiting loop.
# NO LISTINGS: No listings found on page 4, Bellarine, 3221. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Geelong Mc, 3221 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 6, Anakie, 3221. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Grey River, 3221 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Kennett River, 3221 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Lovely Banks, 3221 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 7, Batesford, 3221. Exiting loop.
# NO LISTINGS: No listings found on page 4, Gnarwarre, 3221. Exiting loop.
# NO LISTINGS: No listings found on page 15, Grovedale, 3216. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Separation Creek, 3221 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Staughton Vale, 3221 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 14, Geelong, 3220. Exiting loop.
# NO LISTINGS: No listings found on page 1, Sugarloaf, 3221. Exiting loop.
# NO LISTINGS: No listings found on page 16, Highton, 3216. Exiting loop.
# NO LISTINGS: No listings found on page 15, Marshall, 3216. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Wye River, 3221 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 12, Barrabool, 3221. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Clifton Springs, 3222 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 4, Murgheboluc, 3221. Exiting loop.
# NO LISTINGS: No listings found on page 2, Wongarra, 3221. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Marcus Hill, 3222 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 4, Moorabool, 3221. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Indented Head, 3223 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, St Leonards, 3223 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 3, Curlewis, 3222. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Point Lonsdale, 3225 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 16, Newtown, 3220. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Swan Bay, 3225 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 5, Stonehaven, 3221. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Swan Island, 3225 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Ocean Grove, 3226 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Barwon Heads, 3227 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Queenscliff, 3225. Exiting loop.
# NO LISTINGS: No listings found on page 12, Ceres, 3221. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Bells Beach, 3228 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Jan Juc, 3228 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 5, Wallington, 3221. Exiting loop.
# NO LISTINGS: No listings found on page 4, Leopold, 3224. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Aireys Inlet, 3231 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 5, Mannerim, 3222. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Eastern View, 3231 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Big Hill, 3231 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 4, Portarlington, 3223. Exiting loop.
# NO LISTINGS: No listings found on page 5, Drysdale, 3222. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Moggs Creek, 3231 likely due to incorrect suburb name. Status code: 404. Exiting loop.SUBURB_NOT_FOUND: Failed to retrieve page 1, Apollo Bay, 3233 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 3, Breamlea, 3227. Exiting loop.
#
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Cape Otway, 3233 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Petticoat Creek, 3233 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Skenes Creek, 3233 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Skenes Creek North, 3233 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 22, Breakwater, 3219. Exiting loop.
# NO LISTINGS: No listings found on page 22, Belmont, 3216. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Deans Marsh, 3235 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Mount Sabine, 3236 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Lorne, 3232. Exiting loop.
# NO LISTINGS: No listings found on page 2, Fairhaven, 3231. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Beech Forest, 3237 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Aire Valley, 3237 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 1, Ferguson, 3237. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Gellibrand Lower, 3237 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Wattle Hill, 3237 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 1, Weeaproinah, 3237. Exiting loop.
# NO LISTINGS: No listings found on page 2, Marengo, 3233. Exiting loop.NO LISTINGS: No listings found on page 2, Benwerrin, 3235. Exiting loop.
# NO LISTINGS: No listings found on page 2, Boonah, 3235. Exiting loop.
#
# NO LISTINGS: No listings found on page 1, Wyelangta, 3237. Exiting loop.
# NO LISTINGS: No listings found on page 1, Yuulong, 3237. Exiting loop.
# NO LISTINGS: No listings found on page 2, Forrest, 3236. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Carlisle River, 3239 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Lavers Hill, 3238 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Hordern Vale, 3238 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Pennyroyal, 3235. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Kennedys Creek, 3239 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 1, Johanna, 3238. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Chapple Vale, 3239 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 11, Moolap, 3221. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Mount Moriac, 3240 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 4, Anglesea, 3230. Exiting loop.
# NO LISTINGS: No listings found on page 2, Glenaire, 3238. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Winchelsea South, 3241 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Modewarre, 3240. Exiting loop.
# NO LISTINGS: No listings found on page 2, Gherang, 3240. Exiting loop.
# NO LISTINGS: No listings found on page 2, Gellibrand, 3239. Exiting loop.
# NO LISTINGS: No listings found on page 2, Bambra, 3241. Exiting loop.
# ...
# NO LISTINGS: No listings found on page 2, Alberton, 3971. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Devon North, 3971 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Calrossie, 3971. Exiting loop.
# NO LISTINGS: No listings found on page 2, Gelliondale, 3971. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Jack River, 3971 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Hiawatha, 3971. Exiting loop.
# NO LISTINGS: No listings found on page 2, Hunterston, 3971. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Macks Creek, 3971 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Langsborough, 3971. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Manns Beach, 3971 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Port Albert, 3971 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 5, Balook, 3971. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Robertsons Beach, 3971 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Madalya, 3971. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Staceys Bridge, 3971 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Tarra Valley, 3971 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Won Wron, 3971 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Tarraville, 3971. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Hampton Park, 3976 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Cannons Creek, 3977 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Cranbourne East, 3977 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Cranbourne North, 3977 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Yarram, 3971. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Cranbourne South, 3977 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Cranbourne West, 3977 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Devon Meadows, 3977 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Five Ways, 3977 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Junction Village, 3977 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Clyde North, 3978 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Glen Alvie, 3979 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Korrine, 3979 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Almurta, 3979. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Blind Bight, 3980 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Kernot, 3979. Exiting loop.
# NO LISTINGS: No listings found on page 7, Cranbourne, 3977. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Heath Hill, 3981 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Bayles, 3981. Exiting loop.
# NO LISTINGS: No listings found on page 2, Catani, 3981. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Koo Wee Rup, 3981 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Koo Wee Rup North, 3981 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Adams Estate, 3984 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Yannathan, 3981. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Coronet Bay, 3984 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Jam Jerrup, 3984 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Corinella, 3984. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Lang Lang, 3984 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Caldermeade, 3984. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Lang Lang East, 3984 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Pioneer Bay, 3984 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 10, Skye, 3977. Exiting loop.
# NO LISTINGS: No listings found on page 2, Grantville, 3984. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Tenby Point, 3984 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Monomeith, 3984. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, The Gurdies, 3984 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 7, Warneet, 3980. Exiting loop.
# NO LISTINGS: No listings found on page 2, Queensferry, 3984. Exiting loop.
# NO LISTINGS: No listings found on page 14, Lynbrook, 3975. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Mountain View, 3988 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 14, Lyndhurst, 3975. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Poowong East, 3988 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Nyora, 3987. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Poowong North, 3988 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, St Helier, 3989 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Poowong, 3988. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Glen Forbes, 3990 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 9, Dalmore, 3981. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Blackwood Forest, 3992 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 14, Cardinia, 3978. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, West Creek, 3992 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Dalyston, 3992. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Archies Creek, 3995 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Ryanston, 3992. Exiting loop.
# NO LISTINGS: No listings found on page 3, Bass, 3991. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Cape Paterson, 3995 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Harmers Haven, 3995 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Hicksborough, 3995 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 3, Anderson, 3995. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Lance Creek, 3995 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 14, Clyde, 3978. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, North Wonthaggi, 3995 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Powlett River, 3995 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, South Dudley, 3995 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, St Clair, 3995 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 3, Kilcunda, 3995. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Wattle Bank, 3995 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 14, Tooradin, 3980. Exiting loop.
# NO LISTINGS: No listings found on page 2, Wonthaggi, 3995. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Pound Creek, 3996 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, East Melbourne, 8002 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8001 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 2, Woolamai, 3995. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Administrative Postcode Only, 8003 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Administrative Postcode Only, 8004 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# NO LISTINGS: No listings found on page 3, Inverloch, 3996. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, World Trade Centre, 8005 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Administrative Postcode Only, 8006 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Administrative Postcode Only, 8007 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Administrative Postcode Only, 8008 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Administrative Postcode Only, 8009 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Administrative Postcode Only, 8010 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8045 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8051 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8060 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8061 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8066 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8069 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8070 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8071 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8100 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8101 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8102 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8103 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8107 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8108 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8111 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8120 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8205 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8383 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8386 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8388 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8390 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8393 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8394 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8396 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Melbourne, 8399 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, North Melbourne, 8500 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Carlton, 8507 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Brunswick, 8538 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Fitzroy, 8557 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Ivanhoe, 8576 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Hawthorn, 8622 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Camberwell, 8626 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Camberwell, 8627 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Administrative Postcode Only, 8659 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Dandenong, 8785 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, South Melbourne, 8865 likely due to incorrect suburb name. Status code: 404. Exiting loop.
# SUBURB_NOT_FOUND: Failed to retrieve page 1, Port Melbourne, 8873 likely due to incorrect suburb name. Status code: 404. Exiting loop.

# %%
# Convert to DataFrame and save to CSV
links_df = pd.DataFrame(property_links, columns=['property_link'])
links_df.drop_duplicates(inplace=True)

# Save to parquet file
links_df.to_parquet('../../data/raw/property_links.parquet', index=False)

# %%
len(links_df)
# Out:
# 14459

# %%
property_df = scrape_properties_threaded(links_df['property_link'], 200)

property_df.head()
# Out:
# Failed to retrieve page https://www.domain.com.au/407-33-blackwood-street-north-melbourne-vic-3051-16672345. Status code: 500. Exiting loop.
# Failed to retrieve page https://www.domain.com.au/22-200-wattletree-road-malvern-vic-3144-17185487. Status code: 500. Exiting loop.
#                                                title  \
# 0  60 Little Windrock Lane, Craigieburn VIC 3064 ...
# 1  53 Were Street, Brighton VIC 3186 - House For ...
# 2  43 Tackle Drive, Point Cook VIC 3030 - Townhou...
# 3  3 Rostrevor Parade, Mont Albert VIC 3127 - Hou...
# 4  48 Roberts Street, Frankston VIC 3199 - Studio...
#
#                                          description  \
# 0  View this 2 bedroom, 1 bathroom rental house a...
# 1  View this $1,500/week 4 bedroom, 2 bathroom re...
# 2  View this 3 bedroom, 2 bathroom rental townhou...
# 3  View this 5 bedroom, 2 bathroom rental house a...
# 4  View this 9 bedroom, 3 bathroom rental studio ...
#
#                                   street_address       suburb postcode  \
# 0  60 Little Windrock Lane, Craigieburn VIC 3064  Craigieburn     3064
# 1              53 Were Street, Brighton VIC 3186     Brighton     3186
# 2           43 Tackle Drive, Point Cook VIC 3030   Point Cook     3030
# 3       3 Rostrevor Parade, Mont Albert VIC 3127  Mont Albert     3127
# 4          48 Roberts Street, Frankston VIC 3199    Frankston     3199
#
#            price  bedrooms  bathrooms  parking primary_property_type  \
# 0  $450 Per Week       2.0        1.0      1.0                 House
# 1      $1,490.00       4.0        2.0      2.0                 House
# 2  $550 per Week       3.0        2.0      2.0       Townhouse/Villa
# 3    $800 weekly       5.0        2.0      2.0                 House
# 4  $299 per week       9.0        3.0      4.0             Apartment
#
#                                    property_features  \
# 0                                               None
# 1                                               None
# 2  Air conditioning, Ensuite, Built in wardrobes,...
# 3                                               None
# 4  Furnished, Heating, Modern Bathroom, Modern Ki...
#
#                                  structured_features  video_count  \
# 0  [{'name': 'Built in wardrobes', 'category': 'I...          0.0
# 1                                                 []          0.0
# 2  [{'name': 'Secure Parking', 'category': 'Outdo...          0.0
# 3                                                 []          0.0
# 4  [{'name': 'Furnished', 'category': 'Indoor', '...          0.0
#
#    photo_count              date_listed  days_listed  floor_plans_count  \
# 0         21.0  2024-08-22T16:07:26.000         14.0                0.0
# 1          6.0  2024-06-02T18:11:41.000         95.0                2.0
# 2         17.0  2024-09-03T12:01:18.000          2.0                0.0
# 3          8.0  2024-07-01T12:53:48.000         66.0                0.0
# 4         20.0  2024-07-02T11:24:10.000         65.0                1.0
#
#   virtual_tour nbn_details                                     nearby_schools
# 0        False        None  [{'id': '', 'educationLevel': 'primary', 'name...
# 1         True        None  [{'id': '11562', 'educationLevel': 'combined',...
# 2         True        None  [{'id': '', 'educationLevel': 'combined', 'nam...
# 3        False        None  [{'id': '2804', 'educationLevel': 'primary', '...
# 4        False        None  [{'id': '1717', 'educationLevel': 'primary', '...

# %%
# Drop rows where title, postcode = None (Could not scrape)
property_df = property_df[property_df['title'].notnull()]
property_df = property_df[property_df['postcode'].notnull()]
len(property_df)
# Out:
# 14446

# %%
property_df.to_parquet(f'../../data/raw/property_details.parquet', index=False)
